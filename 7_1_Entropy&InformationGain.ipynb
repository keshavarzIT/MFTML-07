# %%
import numpy as np

# %%
def nodeEntropy(a,b):
    sum = a+b
    if a==0 or b==0:
        return 0
    else:
        return -((a/sum)*np.log2(a/sum))-((b/sum)*np.log2(b/sum))

# %%
def InformationGain(E_old, E_new):
    return E_old-E_new
