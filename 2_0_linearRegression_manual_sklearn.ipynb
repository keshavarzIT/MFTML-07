# %% [markdown]
# <span style="background-color: white; color: black; font-size: 20px; padding: 6px 10px; border-radius: 4px;">
# Linear Regression manual
# </span>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as  pd

# %%
np.random.seed(7)
x = np.random.randint(1,10,(4,1))
x0 = np.ones_like(x)
X = np.concatenate((x0,x), axis=1)
y = np.random.rand(4)
y
# Out:
# array([0.72346518, 0.97798951, 0.53849587, 0.50112046])

# %%
m = len(x)
w = np.linalg.inv(X.T@X)@X.T@y
y_hat = X@w
error = y_hat-y
loss = np.sum(error**2)/m
loss, w
# Out:
# (np.float64(0.0006609628075474735), array([-0.07836782,  0.15272711]))

# %% [markdown]
# <span style="background-color: white; color: black; font-size: 20px; padding: 6px 10px; border-radius: 4px;">
# Linear Regression with sklearn
# </span>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
lr = LinearRegression()
lr.fit(x, y)
y_hat = lr.predict(x)
loss = mean_squared_error(y, y_hat)
w = []

w.append(lr.intercept_)
w.append(lr.coef_[0])
loss, w
# Out:
# (0.0006609628075474757,
#  [np.float64(-0.07836781896121614), np.float64(0.152727114987139)])
